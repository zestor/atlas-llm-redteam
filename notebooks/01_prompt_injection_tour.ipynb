# %% [markdown]
# # 01 — Prompt Injection Tour
#
# **ATLAS:** AML.T0051 | **OWASP:** LLM01
#
# An interactive tour of direct and indirect prompt injection using the `datasets/prompt_injection/` seed corpus and the toolkit's exploit class. Defensive purpose: measure how a model you own responds to each attack family.

# %%
import json, sys
sys.path.append('..')
from atlas.techniques.AML_T0051_prompt_injection.exploit import PromptInjectionExploit

# %% [markdown]
# ## Load the seed dataset
# Each line is an `AdversarialExample`-style record.

# %%
rows = [json.loads(l) for l in open('../datasets/prompt_injection/seed_direct.jsonl')]
print(f'Loaded {len(rows)} direct injection examples')
rows[0]

# %% [markdown]
# ## Define your target
# Replace `toy_target` with a real model client (OpenAI, Anthropic, Ollama).

# %%
def toy_target(prompt: str) -> str:
    # TODO: call your model here
    return 'I cannot comply with that.'

exploit = PromptInjectionExploit(target=toy_target)

# %% [markdown]
# ## Run direct + indirect injection and compute ASR

# %%
direct = exploit.run_direct()
indirect = exploit.run_indirect()
findings = direct + indirect
print(f'Findings: {len(findings)} | ASR: {exploit.asr(findings, 7):.0%}')
for f in findings[:5]:
    print(f'  [{f.severity}] {f.atlas_technique} — {f.finding}')

# %% [markdown]
# ## Takeaways
# - Direct injection is easy to filter; indirect is the real risk.
# - See [defenses/input-validation](../wiki/03_defenses/input-validation.md).
